# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 2</b>
#
# Привет еще раз. Спасибо, что доделал работу. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.
#
# </div>

# %% [markdown]
# <b>Комментарий от ревьюера</b>
#
# Привет! Меня зовут Ярослав Кальманов, я буду делать ревью твоего проекта. Давай будем общаться на «ты».
#
# Мои комментарии будут в ячейках "Комментарий от ревьюера".
#
# <div class="alert alert-danger">
# Красным цветом обозначены комментарии, на которые тебе нужно обратить внимание в первую очередь, чтобы я принял проект.
# </div>
# <div class="alert alert-warning">
# Желтым цветом отмечено то, что ты можешь сделать немного по-другому. Ты можешь учесть эти комментарии при выполнении следующих проектов.
# </div>
# <div class="alert alert-success">
# Зелёным цветом обозначены твои удачные решения, которые ты без сомнения можешь применять в будущих проектах.
# </div>
#
# Если ты вносишь изменения в проект по моим рекомендациям, указывай, пожалуйста, это в своих комментариях. Будет удобно, если обозначишь свои комментарии заметным цветом или поместишь
#
# <div class="alert alert-info">
#
# в такую ячейку
# </div>
#
# Давай при работе с проектом мы будем общаться с тобой в диалоге, поэтому не удаляй и не перемещай мои комментарии, это поможет мне сделать повторную  проверку проекта быстрее.
# ___

# %% [markdown]
# # <a id="0.1"></a>Содержание (кликабельное):
# 0. [Описание проекта](#0), [описание данных](#data), [импорт библиотек](#import)
# 1. [(Шаг 1) Ознакомление с данными:](#1)
#     * [1.1. Общая информация о датафрейме](#1.1)
#     * [1.2. В каких столбцах меняем типы данных](#1.2)
#     * [1.3. Информация о пропусках, методы их заполнения](#1.3)
# 2. [(Шаг 2) Подготовка данных:](#2)
#     * [2.1. Приведение названий столбцов к нижнему регистру](#2.1)
#     * [2.2. Изменение типа данных по столбцу user_score](#2.2)
#     * [2.3. Обработка пропусков](#2.3)
#     * [2.4. Отдельный столбец с суммой продаж по всем регионам 'sales_total'](#2.4)
# 3. [(Шаг 3) Исследовательский анализ данных](#3)
#     * [3.1. Функция для прорисовки bar-графиков create_any_bar](#3.1)
#     * [3.2. Количество выпущенных игр по годам](#3.2)
#     * [3.3. Количество выпущенных игр по платформам.](#3.3)
#     * [3.4. Количество проданных игр по платформам.](#3.4)
#     * [3.5. Динамика продаж игр по платформам](#3.5)
#         * [3.5.1. Распределение продаж самых популярных платформ по годам](#3.5.1)
#         * [3.5.2. График динамики продаж по годам по каждой платформе](#3.5.2)
#         * [3.5.3. График динамики продаж по годам по топ-6 платформ](#3.5.3)
#     * [3.6. Динамика продаж игр в наше время](#3.6)
#     * [3.7. Boxplot по глобальным продажам игр и с разбивкой по платформам](#3.7)
#         * [3.7.1. Функция для прорисовки boxplot create_any_sales_boxplot](#3.7.1)
#         * [3.7.2. Boxplot по глобальным продажам игр](#3.7.2)
#         * [3.7.3. Boxplot по наиболее популярным на конец 2016 года платформам](#3.7.3)
#     * [3.8. Влияние отзывов пользователей и критиков на продажи](#3.8)
#         * [3.8.1. Диаграмма рассеяния зависимости общего коичества продаж игры от отзывов критиков](#3.8.1)
#         * [3.8.2. Матрица корреляции](#3.8.2)
#         * [3.8.3. Данные по корреляции по топовым платформам](#3.8.3)
#     * [3.9. Распределение игр по жанрам](#3.9)
# 4. [(Шаг 4) Портрет пользователя регионов NA, EU, JP:](#4)
#     * [4.1. Функция для прорисовки графиков top_in_regions_plot](#4.1)
#     * [4.2. Определение самых популярных платформ в заданных регионах](#4.2)
#     * [4.3. Определение самых популярных жанров в заданных регионах](#4.3)
#     * [4.4. Влияние рейтинга ESRB на продажи в отдельном регионе](#4.4)
# 5. [(Шаг 5) Проверка гипотез:](#5)
#     * [5.1. Гипотеза № 1 (о равенстве средних пользовательских рейтингов на XBox One и PC)](#5.1)
#     * [5.2. Гипотеза № 2 (о равенстве средних пользовательских рейтингов жанров Action и Sports)](#5.2)
# 6. [(Шаг 6) Общий вывод](#6)

# %% [markdown]
# # <a id="0"></a>Описание проекта
# [к содержанию](#0.1)

# %% [markdown]
# Вы работаете в интернет-магазине **«Стримчик»**, который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, **Xbox** или **PlayStation**). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Не важно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура **ESRB (Entertainment Software Rating Board)** — это ассоциация, определяющая возрастной рейтинг компьютерных игр. **ESRB** оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# # <a id="data"></a>Описание данных

# %% [markdown]
# - **Name** — название игры
# - **Platform** — платформа
# - **Year_of_Release** — год выпуска
# - **Genre** — жанр игры
# - **NA_sales** — продажи в Северной Америке (миллионы долларов)
# - **EU_sales** — продажи в Европе (миллионы долларов)
# - **JP_sales** — продажи в Японии (миллионы долларов)
# - **Other_sales** — продажи в других странах (миллионы долларов)
# - **Critic_Score** — оценка критиков (максимум 100)
# - **User_Score** — оценка пользователей (максимум 10)
# - **Rating** — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Хорошее начало
# </div>

# %% [markdown]
# # <a id="import"></a>Импорт библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mlp
from scipy.stats import ttest_ind
import seaborn as sns

# %% [markdown]
# # <a id="1"></a>Шаг 1. Ознакомление с данными
# [к содержанию](#0.1)

# %% [markdown]
# Загружаем данные:

# %%
games = pd.read_csv('/datasets/games.csv')

# %%
games.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# В первых 10 строках уже немало пропусков - не очень хороший знак.
#
# Посмотрим общую информацию о датафрейме:

# %% [markdown]
# <a id="1.1"></a>**1.1. Общая информация о датафрейме.**
#
# [к содержанию](#0.1)

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Пропусков много. Посмотрим их подробнее чуть ниже.

# %% [markdown]
# <a id="1.2"></a>**1.2. В каких столбцах меняем типы данных.**
#
# [к содержанию](#0.1)

# %% [markdown]
# - **user_score** - это же численный показатель, а имеет тип **object** - меняем на **'float'**.
#
# Остальные типы столбцов в порядке.

# %% [markdown]
# <a id="1.3"></a>**1.3. Информация о пропусках, методы их заполнения.**
#
# [к содержанию](#0.1)

# %% [markdown]
# Визуализируем картину, чтоб понять объем бедствия по пропускам:

# %%
def percent_hbar(df, old_threshold=None):
    percent_of_nulls = (df.isnull().sum()/len(df)*100).sort_values().round(2)
    threshold = percent_of_nulls.mean()
    ax = percent_of_nulls.plot(kind='barh', figsize=(19, 8), title='% of NaN (из {} строк)'.format(len(df)), 
                               color='#30a6ca', legend=False, fontsize=13)
    ax.set_xlabel('Count of NaN')
    dict_percent = dict(percent_of_nulls)
    i = 0
    for k in dict_percent:
        color = 'blue'
        if dict_percent[k] > 0:
            if dict_percent[k] > threshold:
                color = 'red'
            ax.text(dict_percent[k]+0.1, i + 0.09, str(dict_percent[k])+'%', color=color, 
                    fontweight='bold', fontsize='large')
        i += 0.98
    if old_threshold is not None:
        plt.axvline(x=old_threshold,linewidth=1, color='r', linestyle='--')
        ax.text(old_threshold+0.3, 10, '{0:.2%}'.format(old_threshold/100), color='r', fontweight='bold', fontsize='large')
        plt.axvline(x=threshold,linewidth=1, color='green', linestyle='--')
        ax.text(threshold+0.3, 7, '{0:.2%}'.format(threshold/100), color='green', fontweight='bold', fontsize='large')
    else:
        plt.axvline(x=threshold,linewidth=1, color='r', linestyle='--')
        ax.text(threshold+0.3, 7, '{0:.2%}'.format(threshold/100), color='r', fontweight='bold', fontsize='large')
    ax.set_xlabel('')
    return ax, threshold

plot, threshold = percent_hbar(games)

# %% [markdown]
# Практически половина данных отсутствует по столбцам **Critic_Score**, **Rating** и **User_Score**. Такая важная описательная характеристика данных как среднее значение количества пропусков в столбце равна 12%.
#
# Как поступим:
#
# - **Critic_Score** - **оценка критиков** - вполне возможно, что игры не оценивались критиками, т.к. тогда не было такого "обычая". Было бы неправильно заполнить рейтинг игры средним или медианой, даже если бы мы их считали внутри для каждого жанра отдельно. Тем не менее, чтобы иметь возможность быстрой фильтрации данных и возможность их беспрепятственно обрабатывать, поставим этим играм рейтинг -1 (вдруг у какой-то игры есть нулевой рейтинг, поставив -1, мы никогда не перемешаем игры с NaN и с реально нулевым рейтингом);
# - **Rating** - **рейтинг от ESRB** - может быть, в те времена не было такой организации, вот и рейтинга от неё тоже нет. Здесь то же самое. Невозможно дать рейтинг игре, посчитав его как среднее рейтингов игр того же жанра. Поставим рейтинг "No ESRB";
# - **User_Score** - те же причины, вероятно, ранее не было сервисов, которые собирали бы рейтинги игроков. Поэтому и присутствуют пропуски. Поступим так же, как и со столбцом Critic_Score.
#
# Столбец **Year_of_Release** (год выпуска игры) имеет 1,6% пропусков. Не много, но неприятно. Средними/медианами эти пропуски не заполнить, эти данные не являются самыми важными для анализа данных, да и пропусков в столбце не так много. Другими словами, целых данных достаточно для анализа, поэтому оставляем как есть.
#
# Ни по одному столбцу заполнить пропуски хотя бы усредненными данными не представляется возможным. Тем не менее, заполним их "нереальными" данными для возможности спокойно работать с этими строками по другим параметрам.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Ты прав, в данном случае для заполнения пропусков лучше всего использовать значения-заглушки.
# </div>

# %% [markdown]
# Всё-таки проверим, преимущественно ли по старым играм есть эти пропуски:

# %%
games.query('Critic_Score.isnull() & Rating.isnull() & User_Score.isnull()')
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Предположение неверно. И по довольно новым играм есть такие пропуски.

# %% [markdown]
# <hr style="border:1px solid gray"> </hr><hr>

# %% [markdown]
# # <a id="2"></a>Шаг 2. Подготовка данных
# [к содержанию](#0.1)

# %% [markdown]
# <a id="2.1"></a>**2.1 Приведение названий столбцов к нижнему регистру**
#
# [к содержанию](#0.1)

# %% [markdown]
# Для удобства работы приведем названия столбцов к нижнему регистру:

# %%
games.columns = games.columns.str.lower()
games['name']= games['name'].str.lower()
games['platform']= games['platform'].str.lower()
games['genre']= games['genre'].str.lower()
games['rating']= games['rating'].str.lower()
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii           2006.0        sports     41.36
# 1         super mario bros.      nes           1985.0      platform     29.08
# 2            mario kart wii      wii           2008.0        racing     15.68
# 3         wii sports resort      wii           2009.0        sports     15.61
# 4  pokemon red/pokemon blue       gb           1996.0  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      e
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      e
# 3     10.93      3.28         2.95          80.0          8      e
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Молодец, что изменил регистр признаков
# </div>

# %% [markdown]
# <a id="2.2"></a>**2.2 Изменение типа данных по столбцу user_score**
#
# [к содержанию](#0.1)

# %% [markdown]
# Посмотрим отдельно столбцы **user_score** - его формат **'object**, что очень странно, ведь если бы там были только числа и NaN'ы, то формат был бы **'float'**:

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# Помимо пропусков, видим **"tbd"**. Посмотрим, сколько их там таких:

# %%
games[games['user_score'] == 'tbd']
# Out:
#                                            name platform  year_of_release  \
# 119                               zumba fitness      wii           2010.0
# 301              namco museum: 50th anniversary      ps2           2005.0
# 520                             zumba fitness 2      wii           2011.0
# 645                                udraw studio      wii           2010.0
# 657    frogger's adventures: temple of the frog      gba              NaN
# ...                                         ...      ...              ...
# 16695                           planet monsters      gba           2001.0
# 16697                          bust-a-move 3000       gc           2003.0
# 16698                          mega brain boost       ds           2008.0
# 16704                                  plushees       ds           2008.0
# 16706             men in black ii: alien escape       gc           2003.0
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %% [markdown]
# **"tbd"** означает **"to be determined"** т. е. еще нет достаточно данных. По факту **"tbd"** является NaN, заменим и NaN, и **"tbd"** на значение -1 и приведем значение столбца к числовому:

# %%
games['user_score'] = games['user_score'].replace('tbd', np.NaN)
games['user_score'] = games['user_score'].astype('float')
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         7590 non-null float64
# rating             9949 non-null object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <a id="2.3"></a>**2.3. Обработка пропусков**
#
# [к содержанию](#0.1)

# %% [markdown]
# У нас к обработке столбцы **name**, **genre**, **critic_score** и **user_score**. Столбцы **name**, **genre**, в них удалим строки с пропусками. Столбцы **critic_score** и **user_score** - заполним пропуски значением -1.

# %%
#Удалим строки с пропусками в столбцах 'name', 'year_of_release', 'genre' т. к. их количество довольно маленькое
games.dropna(subset=['name', 'genre'], inplace=True)

# %%
games['critic_score'] = games['critic_score'].fillna(-1)
games['user_score'] = games['user_score'].fillna(-1)
games['rating'] = games['rating'].fillna('no esrb')
print('Количество пропусков в столбце critic_score - {}'.format(games['critic_score'].isnull().sum()))
print('Количество пропусков в столбце user_score - {}'.format(games['user_score'].isnull().sum()))
# Out:
# Количество пропусков в столбце critic_score - 0
# Количество пропусков в столбце user_score - 0

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Все верно
# </div>

# %% [markdown]
# Посмотрим ещё раз на статистику по пропускам:

# %%
percent_hbar(games, threshold)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fcd0869c890>,
#  0.14636363636363636)

# %% [markdown]
# Другое дело - средний процент незаполненности данных равен 3,8%.

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера</b>
#
# Ты ведь хотел заполнить пропуски в rating значением "No ESRB", лучше это сделать, чтобы игры без рейтинга отразились на графике в разрезе регионов при составлении портретов пользователей.
#
# И в том же абзаце сверху ты хотел оставить пропуски в year_of_release, а потом их удалил. Поправь там описание, пожалуйста
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Я заполнил пропуски rating значением "no esrb". Так же поправил описание по поводу пропусков в year_of_release.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2</b>
#
# 👍
#
# </div>

# %% [markdown]
# <a id="2.4"></a>**2.4. Отдельный столбец с суммой продаж по всем регионам 'sales_total'**
#
# [к содержанию](#0.1)

# %%
games['sales_total'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# # <a id="3"></a>**Шаг 3. Исследовательский анализ данных**
# [к содержанию](#0.1)

# %% [markdown]
# <a id="3.1"></a>**3.1. Функция для прорисовки bar-графиков create_any_bar**
#
# [к содержанию](#0.1)

# %% [markdown]
# Т.к. далее нам придется рисовать не одну диаграмму, напишем под это функцию:

# %%
def create_any_bar(title, xlabel, ylabel, groupby_column, func, y = 'name'):
    plt.style.use('seaborn-pastel')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    df_to_plot = games.groupby(groupby_column)[y]
    if func == 'count':
        df_to_plot_calculated = df_to_plot.count()
        figsize = (15,5)
        plot = df_to_plot_calculated.plot(kind='bar', y=y, figsize=figsize, ec='black')
    elif func == 'sum':
        df_to_plot_calculated = df_to_plot.sum().sort_values()
        figsize = (15,10)
        plot = df_to_plot_calculated.plot(kind='barh', y=y, figsize=figsize, ec='black')

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Молодец, что автоматизируешь код
# </div>

# %% [markdown]
# <a id="3.2"></a>**3.2. Количество выпущенных игр по годам**
#
# [к содержанию](#0.1)

# %% [markdown]
# Посмотрим, сколько игр выпускалось в каждый из представленных в наших данных годов:

# %%
create_any_bar('Количество выпущенных игр по годам', 'Год', 'Количество игр', 'year_of_release', 'count')

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера</b>
#
# Добавь на все графики в проекте названия, подписи осей и легенду (если это нужно)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Сделано.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2</b>
#
# Отлично! Так будет намного проще разобраться в графиках
# </div>

# %% [markdown]
# По графику можно увидеть, что др 1994 выпускалось очень малое количество игр. Потом они начали появляться, сначала на MS-DOS, потом уже на Windows. Резкий скачок по количеству игр, выпущенных в год, произошел в 2002 году. Пик - 2008-2009 года. После этого спад, который вероятнее связан с развитием мобильных игр.

# %% [markdown]
# <a id="3.3"></a>**3.3. Количество выпущенных игр по платформам**
#
# [к содержанию](#0.1)

# %% [markdown]
# Посмотрим на то, сколько игр **выпускалось** на каждую платформу за весь анализируемый период:

# %%
create_any_bar('Количество выпущенных игр по платформам', 'Платформы', 'Количество игр', 'platform', 'count')

# %% [markdown]
# Количество выпущенных игр на платформах **PS2** и **DS** почти одинаковое и составляет приблизительно **25%** от всех выпущенных игр за этот период.

# %% [markdown]
# <a id="3.4"></a>**3.4. Количество проданных игр по платформам**
#
# [к содержанию](#0.1)

# %%
create_any_bar('Количество проданных игр по платформам', 'Продажи', 'platform', 'platform', 'sum', 'sales_total')

# %% [markdown]
# Безусловным лидером по продажам является платформа **PS2**. Ожидаемо, она у всех давно на слуху. Каждый играл на ней, как минимум, в детстве.
# Далее идут **Xbox360**, **PS3** и **Wii**.
# Самые редкие платформы - представители японских технологий.

# %% [markdown]
# <a id="3.5"></a>**3.5. Динамика продаж игр по платформам**
#
# [к содержанию](#0.1)

# %% [markdown]
# Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам. Ответим на вопрос: за какой характерный срок появляются новые и исчезают старые платформы?

# %% [markdown]
# <a id="3.5.1"></a>**3.5.1. Распределение продаж самых популярных платформ по годам**
#
# [к содержанию](#0.1)

# %% [markdown]
# Выберем топ 6 (а не топ 5, т.к. всё-таки **PS** надо взять в разработку, да и топ-6 близок к топ-5, а вот между топ-6 и топ-7 уже пропасть по выручке):

# %%
platform_filtered = ['ps2', 'x360', 'ps3', 'wii', 'ds', 'ps',] # создаю список с топовыми платформами по продажам
 
platform_top = games.query('platform in @platform_filtered').pivot_table(index='platform',columns='year_of_release',values='sales_total',aggfunc='sum')
platform_top = games.query('platform in @platform_filtered').pivot_table(index='year_of_release',columns='platform',values='sales_total',aggfunc='sum')

# %%
ax = platform_top.plot(title = 'Распределение продаж самых популярных платформ по годам',
                  xlim=(1993, 2016), 
                  grid=True, 
                  figsize=(15, 7), 
                  colormap="gist_rainbow", 
                  linewidth=4.0)
ax.set_xlabel("Год")
ax.set_ylabel("Продажи")
plt.show()

# %% [markdown]
# Посмотрим, сколько "живут" консоли.
#
# - ps - прожила с 1994 года до 2003, почти 10 лет;
# - ps2 - с 2000 до 2011 года - 11 лет;
# - ps3 - с 2006 по настоящее время ещё живёт, но начала сильно сдавать позиции с выходом в 2013 году PS4;
# - ds - вышла в 1985, потом вообще нет данных, скорее всего, по той причине, что они не собирались. И с 2004 года популярность стала расти, пик в 2008, конец срока службы - 2013 год - 8 активных лет жизни;
# - wii - с 2006 по нынешний день, но в 2016 уже почти изжила себя - опять 10 лет.
# - x360 - с 2005 по нынешний день, но в 2016 уже почти изжила себя - 11.
#
# Таким образом, в среднем консоль живет 10 лет. И жила бы больше, если б не выходили более новые консоли. Но это неизбежно, т.к. прогресс идет вперед и "железо" в старых консолях перестает отвечать техническим требованиям новых игр.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Молодец, ты правильно определил продолжительность жизни платформ
#
# </div>

# %% [markdown]
# <a id="3.6"></a>**3.6. Динамика продаж игр в наше время.**
#
# [к содержанию](#0.1)

# %% [markdown]
# Нам необходимо выбрать актуальный период - период, за который мы будем оценивать наши данные, на основании выводов по которым будем строить предсказательные модели на 2017 год.
#
# На мой взгляд, актуальным периодомявляется период с 2005 по 2016 год:
#
# - это год, когда вышли или вот-вот выйдут все популярные консоли;
# - в этом периоде представлены данные по абсолютно всем самым популярным консолям.
#
# Предыдущие года отбросим.
#
# Построим ещё один график, отображающий динамику продаж по уже актуальным годам и ответим на вопрос:
# Какие платформы лидируют по продажам, растут или падают?
#
# На основании полученных данных выберем несколько потенциально прибыльных платформ.

# %%
platform = games.pivot_table(index='platform',columns='year_of_release',values='sales_total',aggfunc='sum')
platform = games.pivot_table(index='year_of_release',columns='platform',values='sales_total',aggfunc='sum')
platform.plot(title = 'Динамика продаж игр в наше время',
              xlim=(2011, 2016),
              grid=True,
              figsize=(16, 10),
              colormap="gist_rainbow",
              linewidth=4.0)
ax.set_xlabel("Год")
ax.set_ylabel("Продажи")
plt.legend(loc="upper left")

# %% [markdown]
# На конец 2016 года лидируют по продажам следующие платформы:
#
# - **ps4**
# - **xone**
# - **3ds**
#
# Это топ-3. Причем, исходя из данных, количество продаж игр, выпущенных на каждую из этих платформ, снижается. Таким образом, можно сказать, что весь рынок игр падает.
#
# Видно что пик продаж у 2 из 3 перспективных платформ **ps4** и **xone** наступает через 2 года после релиза, а у **3ds** пик наступил в первый же год ее существования.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Молодец, что нашел перспективные платформы
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера</b>
#
# Нужно уменьшить актуальный период.
#
# Если мы будем рассматривать данные с 2005 по 2016 гг, то захватим период смены тренда на рынке видеоигр, плюс мы видим по графику выше, что многие платформы за это время успели потерять свою популярность.
#
# Еще подумай, пожалуйста, о жизненном цикле продукта, через сколько лет после релиза у платформ наступает пик продаж? Будет здорово, если в актуальный период не попадут старые тренды, которые могут негативно повлиять на наши рекомендации.
# </div>

# %% [markdown]
# **<div class="alert alert-info">Беру период с 2011 по 2016 гг т. к. в 2011 появилась приставка 3ds - одня из 3 перспективных платформ. Добавил в комментариях про пик продаж.</div>**

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2</b>
#
# Супер, данных с 2011 года нам хватит для прогноза на 2017 год
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера</b>
#
# Дальше нужно исследовать данные только за актуальный период. Нам нужно сделать прогноз на следующий год, а не проанализировать весь рынок видеоигр
# </div>

# %% [markdown]
# <a id="3.7"></a>**3.7. Boxplot по глобальным продажам игр и с разбивкой по платформам.**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# Построим график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Оценим разницу в продажах и в средних продажах на разных платформах. Опишем результат.

# %% [markdown]
# <a id="3.7.1"></a>**3.7.1. Функция для прорисовки boxplot create_any_sales_boxplot.**</br>
#
# [к содержанию](#0.1)

# %%
def create_any_sales_boxplot(title=None, query_condition = None, ylims=None):
    # %matplotlib inline
    if query_condition == None:
        ax = games.boxplot(column='sales_total', fontsize=25, figsize=(25,10),
                                         boxprops=dict(linestyle='-', linewidth=5),
                                         medianprops=dict(linestyle='-', linewidth=5),
                                         whiskerprops=dict(linestyle='-', linewidth=5),
                                         capprops=dict(linestyle='-', linewidth=5), 
                                         notch=True)
    else:
        df_query = games.query(query_condition)
        by_column = query_condition.split()[0]
        ax = df_query.boxplot(column='sales_total', by=by_column, fontsize=25, figsize=(25,10),
                                         boxprops=dict(linestyle='-', linewidth=5),
                                         medianprops=dict(linestyle='-', linewidth=5),
                                         whiskerprops=dict(linestyle='-', linewidth=5),
                                         capprops=dict(linestyle='-', linewidth=5),
                                         notch=True)
        ax.set_xlabel('')
        ax.set_title('')
    if ylims != None:
        ax.set_ylim(ylims)
    if title != None:
        plt.suptitle(title, y=0.94, fontsize=25, fontweight='bold')

# %% [markdown]
# <a id="3.7.2"></a>**3.7.2. Boxplot по глобальным продажам игр.**</br>
#
# [к содержанию](#0.1)

# %%
create_any_sales_boxplot('Boxplot по глобальным продажам игр')

# %% [markdown]
# Посмотрим ближе:

# %%
create_any_sales_boxplot('Boxplot по глобальным продажам игр', ylims=[0,3])
games['sales_total'].describe()
# Out:
# count    16713.000000
# mean         0.533315
# std          1.548282
# min          0.000000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.540000
# Name: sales_total, dtype: float64

# %%
# функция, получающая на вход название признака, и возвращающая границы "усов"
def det_whiskers(column):
    stat = games[column].describe()
    
    # межквартирльный размах
    iqr = stat[6] - stat[4]
    
    # левый и правый "ус"    
    left_whisker = round(stat[4] - 1.5 * iqr, 2)
    right_whisker = round(stat[6] + 1.5 * iqr, 2)

    # левый "ус" не должен быть меньше минимального значения
    if left_whisker < stat[3]: left_whisker = stat[3] 
        
    # правый "ус" не должен быть больше максимального значения
    if right_whisker > stat[7]: right_whisker = stat[7]
        
    return [left_whisker, right_whisker]

# %%
det_whiskers('sales_total')
# Out:
# [0.0, 1.08]

# %% [markdown]
# Медиана - 0.17 млн копий. Средняя - 0.54 млн копий. В общем обычно продажи не превышают 1.08 млн копий, но есть и игры, которые продали десятки миллионов копий.

# %% [markdown]
# <a id="3.7.3"></a>**3.7.3. Boxplot по наиболее популярным на конец 2016 года платформам.**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера</b>
#
# >  Boxplot по наиболее популярным на конец 2016 года платформам.
# > top_platforms = ['ps2', 'x360', 'ps3', 'wii', 'ds', 'ps']
#
# Почему сюда не попали перспективные платформы? Ты уверен, что в 2016 г по ps будут продажи, если уже вышла ps4?
#
# Возьми, пожалуйста, данные за актуальный период и проанализируй их
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Я выбрал в следующем  шаге топ-5 платформ по продажам за период 2011-2016.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2</b>
#
# Молодец, что актуализировал этот раздел
#
# </div>

# %%
actual_games = games[games['year_of_release']>= 2011]
actual_grouped = actual_games.groupby('platform')
actual_grouped['sales_total'].sum().sort_values(ascending=False)
# Out:
# platform
# ps3     445.57
# x360    380.38
# ps4     314.14
# 3ds     257.81
# xone    159.32
# pc       97.68
# wii      95.02
# wiiu     82.19
# psv      53.81
# ds       38.73
# psp      29.01
# ps2       0.45
# Name: sales_total, dtype: float64

# %%
actual_grouped['name'].count().sort_values(ascending=False)
# Out:
# platform
# ps3     708
# 3ds     512
# x360    498
# psv     429
# ps4     392
# pc      389
# psp     312
# xone    247
# wii     197
# ds      184
# wiiu    147
# ps2       7
# Name: name, dtype: int64

# %% [markdown]
# Возьмём топ-5 платформ по продажам за период 2011-2016

# %%
actual_platforms = ['ps3', 'x360', 'ps4', '3ds', 'xone',]
create_any_sales_boxplot('Boxplot продаж по топовым платформам', query_condition="platform in @actual_platforms")
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# Посмотрим ближе:

# %%
create_any_sales_boxplot('Boxplot продаж по топовым платформам', query_condition="platform in @actual_platforms", ylims=[0,3])
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Молодец, что ограничил значения по оси Y
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера</b>
#
# Зачем мы тут пишем миллион одинаковых функций? Напиши одну функцию, а название платформы передавай в виде параметра
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Я удалил эти функции вообще т.к. и без них все понятно.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера</b>
#
# Лучше было написать какой-нибудь вывод, а не описывать график. Например, "медианные продажи ps3 выше, чем у конкурентов, неудивительно, ведь это одна из самых популярных платформ..."
#
# Не очень понятно зачем писать все эти числа (медиану, среднее, максимальное значение). Мы их только что визуализировали, чтобы было проще их воспринимать.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Из топ-5 платформ актуального периода у 3ds в среднем самые низкие продажи игр, однако меньше всего копий продалось у  xone. Это произошло потому что для xone было выпущено в два с лишнем раза меньше игр чем для 3ds. Самой продаваемой платформой является ps3 и за ней x360.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2</b>
#
# Все верно, молодец, что дополнил вывод
#
# </div>

# %% [markdown]
# <a id="3.8"></a>**3.8. Влияние отзывов пользователей и критиков на продажи.**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# За образец возьмем PS3 - она давно на рынке, по ней много данных, при этом даже на конец 2016 года она является одной из самых популярных игровых платформ.

# %%
games_ps3 = games[(games['platform'] == 'ps3') & (games['critic_score'] > 0)].copy()
games_ps3
# Out:
#                                  name platform  year_of_release    genre  \
# 16                 grand theft auto v      ps3           2013.0   action
# 34         call of duty: black ops ii      ps3           2012.0  shooter
# 37     call of duty: modern warfare 3      ps3           2011.0  shooter
# 41            call of duty: black ops      ps3           2010.0  shooter
# 54                     gran turismo 5      ps3           2010.0   racing
# ...                               ...      ...              ...      ...
# 15649                      darksiders      ps3           2010.0   action
# 15742    invizimals: the lost kingdom      ps3           2013.0   action
# 15880        turbo: super stunt squad      ps3           2013.0   sports
# 16146          don bradman cricket 14      ps3           2014.0   sports
# 16230                   madden nfl 13      ps3           2012.0   sports
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %% [markdown]
# <a id="3.8.1"></a>**3.8.1. Диаграмма рассеяния зависимости общего коичества продаж игры от отзывов критиков.**</br>
#
# [к содержанию](#0.1)

# %%
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
games_ps3 = games[(games['platform'] == 'ps3') & (games['critic_score'] > 0)].copy()
games_ps3.plot(kind='scatter', x='critic_score', y='sales_total', ec='black', figsize=(10,6))

# %% [markdown]
# С увеличением среднего рейтинга критиков увеличивается и средний уровень продаж игр, что логично: чем качественнее игра, тем больше денег она приносит разработчику и издателю.

# %% [markdown]
# Теперь от отзывов пользователей:

# %%
games_ps3 = games[(games['platform'] == 'ps3') & (games['user_score'] > 0)].copy()
games_ps3.plot(kind='scatter', x='user_score', y='sales_total', ec='black', figsize=(10,6))

# %% [markdown]
# Точно такая же картина, правда так называемых выбросов больше - когда рейтинг пользователей не велик, но тем не менее платформа делает большие большие продажи. В пример могу привести те же последние игры серии Need for Speed, когда все покупают игру, принося разработчикам прибыль, а потом расстраиваются, увидев, какая эта игра, и ставят ей довольно средние оценки.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Все верно
# </div>

# %% [markdown]
# <a id="3.8.2"></a>**3.8.2. Матрица корреляции**</br>
#
# [к содержанию](#0.1)

# %%
games_ps3 = games[(games['platform'] == 'ps3') & (games['user_score'] > 0) & (games['critic_score'] > 0)].copy()
plt.figure(figsize=(9,9))
sns.heatmap(games_ps3.corr(), annot=True, cmap="Greens", fmt='.2f', annot_kws={'size':16})

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера</b>
#
# Молодец, что убрал отрицательные значения по user_score, но сейчас в games_ps3 есть отрицательные значения по critic_score. Их тоже нужно отфильтровать
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Сделано.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2</b>
#
# 👍
#
# </div>

# %% [markdown]
# Выделим нужные нам данные:

# %%
games_ps3_filtered = games_ps3[['sales_total' ,'critic_score', 'user_score']]
plt.figure(figsize=(1,3))
sns.heatmap(games_ps3_filtered.corr()[['sales_total']].sort_values(by='sales_total', ascending=False), cmap="Greens", 
            annot=True, annot_kws={'size':15})

# %% [markdown]
# Сильнее всего на кроичество проданных копий влияет оценка критиков. Меньше, практически не влияет - оценка пользователей.

# %% [markdown]
# <a id="3.8.3"></a>**3.8.3. Данные по корреляции по топовым платформам**</br>
#
# [к содержанию](#0.1)

# %%
actual_platforms = ['ps3', 'x360', 'ps4', '3ds', 'xone', 'pc']

rows = len(actual_platforms) // 2
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(15,8.5))
count = 0
for r in range(rows):
    for c in range(cols):
        curr_platform = actual_platforms[count]
        df_prep = games[(games['platform'] == curr_platform) & (games['user_score'] > 0) & (games['critic_score'] > 0)].copy()
        
        df_filtered = df_prep[['sales_total' ,'critic_score', 'user_score']]
        sns.set(font_scale=1.0)
        ax = sns.heatmap(df_filtered.corr()[['sales_total']].sort_values(by='sales_total', ascending=False), 
                         cmap="Greens", annot=True, annot_kws={'size':15}, ax=axes[r,c])
        ax.set_title(curr_platform, fontsize=20)
        ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
        plt.tight_layout(pad=3)
        count += 1

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера</b>
#
# Тут тоже нужно убрать отрицательные значения по critic_score
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Сделано.
# </div>

# %% [markdown]
# Данные по корреляции между продажами и оценкой по платформам **ps3, x360, ps4, 3ds** и **xone** более или менее совпадают с общими данными по датафрейму.
# Выделяется **pc**, по которому зависимость не такая большая.
# Кстати, есть платформы, где оценка критиков, согласно данных, сильнее "определяет" конечные продажи продукта, чем оценка пользователей. Это платформы **ps3, ps4**, **x360** и **xone**. Про **ps4** и **xone** - платформы довольно новые, вполне вероятно, что пользователи пока не "освоились", поэтому большого количества отзывов, особенно качественных от них нет.

# %% [markdown]
# <a id="3.9"></a>**3.9. Распределение игр по жанрам.**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# Нарисуем столбчатую диаграмму с количеством выпущенных игр и количеством проданных копий и расскажем о самых продаваемых жанрах, а потом посмотрим на особенности жанров с высокими и низкими продажами.

# %%
ax = plt.gca()

pivot = actual_games.groupby('genre').agg({'name': 'count', 'sales_total': 'sum'}).sort_values(by='name', ascending=False)

plot1 = pivot['name']
plot1.plot(kind='bar', figsize=(15,5), ec='black', ax=ax, width=0.2, position=1)

plot2 = pivot['sales_total']
plot2.plot(kind='bar', figsize=(15,5), ec='black', ax=ax, width=0.2, color='#97F0AA', position=0)

ax.legend(['Количество выпущенных игр', 'Количество проданных копий'])

# %% [markdown]
# Больше всего выпущенных игр жанра **action**. За ними идут игры **role-playing** жанра.
#
# Опишем отдельно топ по количеству выпущенных игр и топ по количеству проданных копий.
#
#
# **Количество выпущенных игр:**
#
# 1. **Action**
# 2. **Role-playing**
# 3. **Adventure**
#
# ...**аутсайдеры** - игры, которые требуют усидчивости:
#
#
# **Количество проданных копий:**
#
# 1. **Action**
# 2. **Shooter**
# 3. **Role-playing**
#
# ...**аутсайдеры** почти те же герои:

# %%
actual_genre = actual_games.groupby('genre')
actual_genre['name'].count().sort_values(ascending=False)
# Out:
# genre
# action          1269
# role-playing     465
# adventure        410
# sports           389
# misc             375
# shooter          329
# racing           180
# fighting         159
# simulation       136
# platform         122
# strategy         117
# puzzle            71
# Name: name, dtype: int64

# %%
actual_genre['sales_total'].median().sort_values(ascending=False)
# Out:
# genre
# shooter         0.410
# sports          0.200
# platform        0.185
# fighting        0.180
# racing          0.160
# role-playing    0.150
# misc            0.130
# action          0.130
# simulation      0.110
# strategy        0.080
# puzzle          0.050
# adventure       0.030
# Name: sales_total, dtype: float64

# %%
actual_genre['sales_total'].sum().sort_values(ascending=False)
# Out:
# genre
# action          557.80
# shooter         402.91
# role-playing    245.63
# sports          237.15
# misc            139.42
# platform         88.68
# racing           88.31
# fighting         66.90
# simulation       50.26
# adventure        45.04
# strategy         22.16
# puzzle            9.85
# Name: sales_total, dtype: float64

# %% [markdown]
# Медианные продажи показывают что несмотря на то, что больше всего продаж у жанра **action**, в среднем каждая игра продает всего 130 тысяч копий, это восьмое место в списке. А вот у игр жанра **shooter**, в среднем продажы каждой игры составляют 410 тысяч копий, сто в более чем в 3 раза превышает показатель жанра **action**. Простыми словами можно сказать что **action** взял количеством т.к. количество выпущенных игр **action** (1269) больше чем три следующие жанра (**role-playing - 465**, **adventure - 410**,
# **sports - 389**) вместе взятых. Кстати у жанра **adventure** один и самых плохих показателей общих продаж - третье место с низу.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Молодец, что рассмотрел суммарные продажи игр и количесто игр по жанрам.
# </div>
#
#
#
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера</b>
#
#
# Мы видим, что количество игр сильно различается в зависимости от жанра, предлагаю посчитать медианные продажи, чтобы понять, какой жанр обычно продается лучше.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Сделано.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2</b>
#
# Молодец, что дополнил исследование
#
# </div>

# %% [markdown]
# <hr style="border:1px solid gray"> </hr><hr>

# %% [markdown]
# # <a id="4"></a>**Шаг 4. Портрет пользователя регионов NA, EU, JP**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# Определим для пользователя каждого региона (NA, EU, JP):
#
# - самые популярные платформы (топ-5), опишем различия в долях продаж;
# - самые популярные жанры (топ-5), поясним разницу;
# - определим, влияет ли рейтинг ESRB на продажи в отдельном регионе.

# %% [markdown]
# <a id="4.1"></a>**4.1. Функция для прорисовки графиков top_in_regions_plot:**</br>
#
# [к содержанию](#0.1)

# %%
def top_in_regions_plot(groupby, region_sales, ax):
    pivot = actual_games.groupby(groupby).agg({region_sales: 'sum'}).sort_values(by=region_sales, ascending=False)[:5]
    title_dict = {'na_sales': 'North America Sales', 'eu_sales': 'Europe Sales', 'jp_sales': 'Japan Sales'}
    color_dict = {'na_sales': None, 'eu_sales': 'gray', 'jp_sales': 'forestgreen'}
    plot = pivot.plot(kind='bar', ec='black', title=title_dict[region_sales], ax=axes[ax], 
                   fontsize=18, color=color_dict[region_sales], rot=20)
    plot.legend(prop={'size':17})
    plot.set_xlabel('')
    plot.title.set_size(20)

# %% [markdown]
# <a id="4.2"></a>**4.2. Определение самых популярных платформ в заданных регионах:**</br>
#
# [к содержанию](#0.1)

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

top_in_regions_plot('platform', 'na_sales', 0)
top_in_regions_plot('platform', 'eu_sales', 1)
top_in_regions_plot('platform', 'jp_sales', 2)

# %% [markdown]
# - В **Северной Америке** имеют бешеную популярность приставки прошлого поколения **X360** и **PS3**. Немного отстает **PS4**. Топ-4 и топ-5 - **XOne** и **3DS** соответственно.
#
# - В **Европе** **PS3** занял первое место, а **PS4**. За ними **X360**, **3DS** и **PC**.
#
# - В **Японии**, как обычно, всё наоборот. Лидер - **3DS**. За ним **PS3** и **PSP**. Топ-4 и топ-5 - **PSV** и **PS4** соответственно.

# %% [markdown]
# <a id="4.3"></a>**4.3. Определение самых популярных жанров в заданных регионах:**</br>
#
# [к содержанию](#0.1)

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

top_in_regions_plot('genre', 'na_sales', 0)
top_in_regions_plot('genre', 'eu_sales', 1)
top_in_regions_plot('genre', 'jp_sales', 2)

# %% [markdown]
# Вкусы в **Северной Америке** и **Европе** схожи: и там, и там живут фанаты **экшнов**, **спортивных игр** и **шутеров**. В Северной Америке больше играют в **игры "смешанного" жанра**, в Европе же чаще выбирают **гонки**.
#
#
# В **Японии** вкус совершенно иной - на первом и втором месте **ролевые игры** и **экшны**, причем с большим отрывом. Далее **игры "смешанного" жанра**.

# %% [markdown]
# <a id="4.4"></a>**4.4. Влияние рейтинга ESRB на продажи в отдельном регионе.**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# **Добавим новый столбец в основной датафрейм с разъяснением, какая буква рейтинга что означает:**

# %%
esrb_dict = {'e': 'Для всех', 'm': '> 17 лет', 't': '13-19 лет', 'e10+': '>10 лет', 'k-a': 'Для всех(устар.)'}

# %%
actual_games['esrb_description'] = actual_games[actual_games['rating'].notnull()]['rating'].map(esrb_dict)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Посмотрим на продажи игр по рейтингу:

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

top_in_regions_plot('esrb_description', 'na_sales', 0)
top_in_regions_plot('esrb_description', 'eu_sales', 1)
top_in_regions_plot('esrb_description', 'jp_sales', 2)

# %% [markdown]
# - В **Северной Америке** и в **Европе** картина практически одинаковая. Большая часть выручки получено с игр с рейтингом **"для лиц старше 17 лет"**, далее **"Для всех"**. В **Северной Америке** на третьем месте **"для лиц старше 10 лет"**, а в **Европе**  **"13-19 лет"**.
#
# - В **Японии** опять не так. Первое место - **"Для всех"**, а вот на втором - игры **для лиц от 13 до 19 лет**.

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера 2</b>
#
# Мы заполнили пропуски в rating, но так как не добавили новое значение в `esrb_dict`, на график пропуски все равно не попали. Поправь этот момент, если будет желание
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Ты хорошо справился с составлением портретов, но нужно изменить рассматриваемый период на актуальный и обновить выводы
# </div>

# %% [markdown]
# <hr style="border:1px solid gray"> </hr><hr>

# %% [markdown]
# # <a id="5"></a>**Шаг 5. Проверка гипотез**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# **Гипотезы:**
#
# - **средние пользовательские рейтинги платформ Xbox One и PC одинаковые;**
# - **средние пользовательские рейтинги жанров Action и Sports разные.**
#
# Для проверки обеих гипотез будем использовать t-критерий Стьюдента, т.к. в обоих случаях выборки независимы между собой.
# Определим пороговое значение alpha = 0.05

# %% [markdown]
# <a id="5.1"></a>**5.1.  Гипотеза № 1:
# средние пользовательские рейтинги платформ Xbox One и PC одинаковые.**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# **Н0 (нулевая гипотеза) - средние пользовательские рейтинги платформ Xbox One и PC одинаковые.**
#
# **Н1 (альтернативная гипотеза) - средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой.**

# %%
actual_games.head()
# Out:
#                               name platform  year_of_release         genre  \
# 16              grand theft auto v      ps3           2013.0        action
# 23              grand theft auto v     x360           2013.0        action
# 29  call of duty: modern warfare 3     x360           2011.0       shooter
# 31       call of duty: black ops 3      ps4           2015.0       shooter
# 33             pokemon x/pokemon y      3ds           2013.0  role-playing
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 29      9.04      4.24      0.13         1.32          88.0         3.4
# 31      6.03      5.86      0.36         2.38          -1.0        -1.0
# 33      5.28      4.19      4.35         0.78          -1.0        -1.0
#
#      rating  sales_total esrb_description
# ...

# %%
xbox_one_ratings = actual_games[(actual_games['platform'] == 'xone') & (actual_games['user_score'] > 0)]['user_score']
pc_ratings = actual_games[(actual_games['platform'] == 'pc') & (actual_games['user_score'] > 0)]['user_score']
stat, p = ttest_ind(xbox_one_ratings, pc_ratings)

print('t = {}\np-value = {:.10e}'.format(stat, p))
print('\nПороговое значение alpha = 0.05')
# Out:
# t = 0.48660071309601444
# p-value = 6.2676022714e-01
#
# Пороговое значение alpha = 0.05

# %% [markdown]
# **Не можем отвергнуть нулевую гипотезу.
# Таким образом, остается верным утверждение, средние пользовательские рейтинги платформ Xbox One и PC одинаковые**

# %% [markdown]
# Проверим:

# %%
print('Средняя оценка пользователей игр для платформы Xbox One  - {:.2f}'.format(xbox_one_ratings.mean()))
print('Средняя оценка пользователей игр для платформы PC - {:.2f}'.format(pc_ratings.mean()))
# Out:
# Средняя оценка пользователей игр для платформы Xbox One  - 6.52
# Средняя оценка пользователей игр для платформы PC - 6.45

# %% [markdown]
# <a id="5.2"></a>**5.2.  Гипотеза № 2:
# средние пользовательские рейтинги жанров Action и Sports разные.**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# **Н0 (нулевая гипотеза) - средние пользовательские рейтинги жанров Action и Sports одинаковые.**
#
# **Н1 (альтернативная гипотеза) - средние пользовательские рейтинги жанров Action и Sports отличаются между собой.**

# %%
action_ratings = actual_games[(actual_games['genre'] == 'action') & (actual_games['user_score'] > 0)]['user_score']
sports_ratings = actual_games[(actual_games['genre'] == 'sports') & (actual_games['user_score'] > 0)]['user_score']
stat, p = ttest_ind(action_ratings, pc_ratings)

print('t = {}\np-value = {:.4f}'.format(stat, p))
print('\nПороговое значение alpha = 0.05')
# Out:
# t = 3.272266278910861
# p-value = 0.0011
#
# Пороговое значение alpha = 0.05

# %% [markdown]
# **Смело отклоняем нулевую гипотезу.
# Верно следующее утверждение: средние пользовательские рейтинги жанров Action и Sports отличаются между собой.**
#
# **Посмотрим в чью пользу:**

# %%
print('Средняя оценка пользователей игр для жанра Action  - {:.2f}'.format(action_ratings.mean()))
print('Средняя оценка пользователей игр для жанра Sports - {:.2f}'.format(sports_ratings.mean()))
# Out:
# Средняя оценка пользователей игр для жанра Action  - 6.78
# Средняя оценка пользователей игр для жанра Sports - 5.65

# %% [markdown]
# **Игры жанра Action получают оценки статистически значимо выше, чем игры жанра Sports. Видимо спорт уже поднадоел и люди ищут побольше "экшена".**

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Молодец, ты правильно сформулировал и проверил гипотезы
# </div>

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# # <a id="6"></a>**Шаг 6. Общий вывод**</br>
#
# [к содержанию](#0.1)

# %% [markdown]
# Следующая **ИГРА ХИТ** - это игра жанра **Shooter** для приставки **PS4** и для аудитории **"старше 17 лет"**
#
# 1. **По проведенному анализу: самое сильное влияние на итоговое количествдо проданных копий оказывают, в большинстве случаев, оценки критиков. Оценки пользователей таким "влиянием" на количествдо продаж похвастаться не могут. Необходимо копать в эту сторону.**
#
# 2. **В целом про положение дел в игровой индустрии: рынок "немобильных" игр постепенно погибает. Все сейчас в погоне за графикой, новыми технологями, в связи с этим средний бюджет на разработку одной игры за последние годы заметно вырос. Более того, сейчас игрок не так ценит идею и глубины игры, большинство может обрадовать только хорошая картинка и оптимизация - а играть им понравится только в том случае, если в игре будут стрелочки куда идти. Иначе это слишком трудно.**
#
# 3. **В итоге, гиганты игровой индустрии гоняются за технологиями, а более мелкие компании, не имеющие таких бюджетов, вынуждены отступать, т.к. единственный их козырь - способность создать глубокую игру с атмосферной - нынче не ценится.**
#
# **Всё это привело к тому, что рынок уже который год падает. И, скорее всего, будет падать, потому что тенденции к изменению ценностей на те, которые были всего с десяток лет назад, нет.**

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера</b>
#
# Нам нужно было:
#
#     Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Мне кажется, этот вывод не сильно поможет сделать прогноз на 2017 год. Будет здорово, если вывод будет соответствовать теме исследования.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Сделано.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2</b>
#
# Молодец, что дополнил вывод
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера</b>
#
# Спасибо за твою работу! Ты хорошо справился с анализом данных и проверкой гипотез, у тебя получились отличные графики и логичные выводы
#
# Осталось немного доработать проект:
#
# - добавить названия на графики
# - уменьшить актуальный период
# - использовать данные за актуальный период для анализа и проверки гипотез
# - убрать одинаковые функции det_whiskers_ds, det_whiskers_ps, ...
# - для расчета корреляции отфильтровать отрицательные значения в critic_score
# - посчитать медианные продажи игр по жанрам
#
# Обрати внимание, что эти изменения могут сильно повлиять на данные. Проверь, пожалуйста, все комментарии и выводы перед отправкой проекта.
#
# Жду твои исправления:)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 2</b>
#
# Спасибо, что учел мои комментарии. Надеюсь, эта работа была полезна для тебя. Я принимаю твой проект и желаю удачи в прохождении курса!
#
# </div>
